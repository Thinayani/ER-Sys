# %% [markdown]
# # Introduction
#
# The dataset for this competition (both train and test) was generated from a deep learning model trained on a [Employee Attrition](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset). Feature distributions are close to, but not exactly the same, as the original.
#
# For each `EmployeeNumber` in the test set, you must predict the probability for the target variable `Attrition`.
#
# ## About Dataset
#
# * `Age`
# * `BusinessTravel`
# * `DailyRate`
# * `Department`
# * `DistanceFromHome`
# * `Education`
# * `EducationField`
# * `EmployeeCount`
# * `EnvironmentSatisfaction`
# * `Gender`
# * `HourlyRate`
# * `JobInvolvement`
# * `JobLevel`
# * `JobRole`
# * `JobSatisfaction`
# * `MaritalStatus`
# * `MonthlyIncome`
# * `MonthlyRate`
# * `NumCompaniesWorked`
# * `Over18`
# * `OverTime`
# * `PercentSalaryHike`
# * `PerformanceRating`
# * `RelationshipSatisfaction`
# * `StandardHours`
# * `StockOptionLevel`
# * `TotalWorkingYears`
# * `TrainingTimesLastYear`
# * `WorkLifeBalance`
# * `YearsAtCompany`
# * `YearsInCurrentRole`
# * `YearsSinceLastPromotion`
# * `YearsWithCurrManager`
# * `Attrition`
#
# Submissions are evaluated on **area under the ROC** curve between the predicted probability and the observed target.

# %% [markdown]
# # Library Import
# * Some library import and some configurations of seaborn.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from pathlib import Path
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder

import lightgbm as lgbm
from xgboost import XGBClassifier, XGBRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from lightgbm.sklearn import LGBMClassifier, LGBMRegressor

sns.set_theme(style='darkgrid')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Data

# %%
DATAPATH = Path('../input/playground-series-s3e3')

train = pd.read_csv(DATAPATH/'train.csv')
test = pd.read_csv(DATAPATH/'test.csv')
sample_sub = pd.read_csv(DATAPATH/'sample_submission.csv')

# %%
original = pd.read_csv('../input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# munging the original data to make it appear more like our train DataFrame
original = original.rename(columns={'EmployeeNumber': 'id'})
original['Attrition'] = (original['Attrition'] == 'Yes').astype(int)

# rearranging columns so that they are in the same order as in train
original = original[train.columns.tolist()]

# adding the source column
original['source'] = 'original'
train['source'] = 'train'
test['source'] = 'test'

# %%
train.head()
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StockOptionLevel  TotalWorkingYears  \
# 0                        4  ...                1                 10
# 1                        1  ...                1                  4
# 2                        3  ...                2                  4
# 3                        3  ...                0                 15
# 4                        2  ...                0                 31
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      2                3             10                   0
# 1                      3                3              4                   2
# 2                      3                3              3                   2
# 3                      1                1              6                   0
# 4                      0                3             31                  14
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  source
# 0                       7                     8          0   train
# 1                       0                     3          0   train
# 2                       1                     2          0   train
# 3                       0                     2          0   train
# 4                       4                    10          1   train
#
# [5 rows x 36 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data Size
# * The dataset is small. We can try out more advanced training and ensembling techniques!

# %%
print('train shape: ', train.shape)
print('original shape: ', original.shape)
print('test shape: ', test.shape)
# Out:
# train shape:  (1677, 36)
# original shape:  (1470, 36)
# test shape:  (1119, 35)

# %%
train.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1677.000000  1677.000000  1677.000000       1677.000000  1677.000000
# mean    838.000000    36.036971   892.749553          8.683959     2.937984
# std     484.252517     8.507112   374.496259          7.826143     1.039078
# min       0.000000    18.000000   107.000000          1.000000     1.000000
# 25%     419.000000    30.000000   589.000000          2.000000     2.000000
# 50%     838.000000    35.000000   890.000000          7.000000     3.000000
# 75%    1257.000000    41.000000  1223.000000         12.000000     4.000000
# max    1676.000000    60.000000  3921.000000         29.000000    15.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1677.0              1677.000000  1677.000000     1677.000000
# mean             1.0                 2.757901    67.798450        2.782349
# std              0.0                 1.086835    19.435928        0.650664
# min              1.0                 1.000000    30.000000        1.000000
# 25%              1.0                 2.000000    51.000000        2.000000
# 50%              1.0                 3.000000    69.000000        3.000000
# 75%              1.0                 4.000000    84.000000        3.000000
# max              1.0                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# count  1677.000000  ...         1677.0       1677.000000        1677.000000
# mean      1.998807  ...           80.0          0.721527          10.709600
# std       1.083065  ...            0.0          0.771259           7.255135
# min       1.000000  ...           80.0          0.000000           0.000000
# 25%       1.000000  ...           80.0          0.000000           6.000000
# 50%       2.000000  ...           80.0          1.000000           9.000000
# 75%       2.000000  ...           80.0          1.000000          14.000000
# max       7.000000  ...           80.0          3.000000          41.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1677.000000      1677.000000     1677.000000
# mean                2.732856         2.769827        6.806798
# std                 1.145271         0.647721        5.883282
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       41.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# count         1677.000000              1677.000000           1677.000000
# mean             4.144305                 1.978533              4.186643
# std              3.583398                 3.045716              3.576189
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 2.000000              7.000000
# max             18.000000                15.000000             17.000000
#
#          Attrition
# count  1677.000000
# mean      0.119261
# std       0.324192
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ## Missing Data
# * There are no missing values!

# %%
total = train.isnull().sum().sort_values(ascending=False)
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(10)
# Out:
#                           Total  Percent
# id                            0      0.0
# Age                           0      0.0
# Over18                        0      0.0
# OverTime                      0      0.0
# PercentSalaryHike             0      0.0
# PerformanceRating             0      0.0
# RelationshipSatisfaction      0      0.0
# StandardHours                 0      0.0
# StockOptionLevel              0      0.0
# TotalWorkingYears             0      0.0

# %%
total = original.isnull().sum().sort_values(ascending=False)
percent = (original.isnull().sum()/original.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(10)
# Out:
#                           Total  Percent
# id                            0      0.0
# Age                           0      0.0
# Over18                        0      0.0
# OverTime                      0      0.0
# PercentSalaryHike             0      0.0
# PerformanceRating             0      0.0
# RelationshipSatisfaction      0      0.0
# StandardHours                 0      0.0
# StockOptionLevel              0      0.0
# TotalWorkingYears             0      0.0

# %% [markdown]
# ## outlier

# %%
train = train.drop(527).drop(1398).reset_index(drop=True)

# %% [markdown]
# ## Data Distributions

# %%
num_features = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'EmployeeCount',
                'MonthlyIncome', 'MonthlyRate','NumCompaniesWorked', 'PercentSalaryHike',
                'StandardHours', 'TrainingTimesLastYear', 'TotalWorkingYears', 'YearsAtCompany', 
                'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

cat_features = ['BusinessTravel', 'Department','Education', 'EducationField', 'EnvironmentSatisfaction', 
                'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 
                'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 
                'TrainingTimesLastYear']

target = 'Attrition'

# %% [markdown]
# ### Numerical Features
# * `EmployeeCount` and `StandardHours` are constant.
# * `Over18` is constant.

# %%
# Train set
fig, axes = plt.subplots(5,3, figsize=(20, 12))
for i, j in zip(num_features, axes.flatten()):
    sns.histplot(train[i], ax=j)
fig.tight_layout()
plt.show()

# %%
# original
fig, axes = plt.subplots(5,3, figsize=(20, 12))
for i, j in zip(num_features, axes.flatten()):
    sns.histplot(original[i], ax=j)
fig.tight_layout()
plt.show()

# %%
# Test set
fig, axes = plt.subplots(5,3, figsize=(20, 12))
for i, j in zip(num_features, axes.flatten()):
    sns.histplot(test[i], ax=j)
fig.tight_layout()
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'Age', bins=20)
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'DailyRate', bins=20)
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'NumCompaniesWorked', bins=20)
plt.show()

# %% [markdown]
# ### Categorical Features

# %%
cat_concat = pd.concat([train[cat_features+['source']], original[cat_features+['source']], test[cat_features+['source']]])

# %%
fig, axes = plt.subplots(17,1, figsize=(25, 80))
for i, j in zip(cat_features, axes.flatten()):
    data = cat_concat.groupby('source')[i].value_counts(True).rename('%').reset_index()
    sns.barplot(data=data, hue='source', x=i, y='%', ax=j)
    j.tick_params(axis='x')
plt.show()

# %%
train = train.drop('EmployeeCount', axis=1)
original = original.drop('EmployeeCount', axis=1)
test = test.drop('EmployeeCount', axis=1)
train = train.drop('StandardHours', axis=1)
original = original.drop('StandardHours', axis=1)
test = test.drop('StandardHours', axis=1)
train = train.drop('Over18', axis=1)
original = original.drop('Over18', axis=1)
test = test.drop('Over18', axis=1)

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'JobInvolvement')
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'JobLevel')
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'JobSatisfaction')
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'WorkLifeBalance')
plt.show()

# %%
g = sns.FacetGrid(train, col='Attrition', height=4, aspect=2)
g.map(plt.hist, 'StockOptionLevel')
plt.show()

# %% [markdown]
# ### Target

# %%
target_concat = pd.concat([train[[target, 'source']], original[[target, 'source']]])

# %%
# Train Set
print('Train Set')
display(pd.DataFrame(train['Attrition'].value_counts()).reset_index().rename(columns={'index':'Attrition', 'Attrition':'count'}))
# Original
print('Original')
display(pd.DataFrame(original['Attrition'].value_counts()).reset_index().rename(columns={'index':'Attrition', 'Attrition':'count'}))
# Out:
# Train Set
#    Attrition  count
# 0          0   1475
# 1          1    200
# Original
#    Attrition  count
# 0          0   1233
# 1          1    237

# %%
fig, ax = plt.subplots(figsize=(10, 6))
data = target_concat.groupby('source')[target].value_counts(True).rename('%').reset_index()
sns.barplot(data=data, hue='source', x=target, y='%')
plt.show()

# %% [markdown]
# ## Construct new features

# %%
def is_young(x):
    if x <=25:
        return 1
    else:
        return 0
    
def young_and_low_daily_rate(x):
    if x['Age'] <= 25 & x['DailyRate'] < 500:
        return 1
    else:
        return 0

# %%
train['is_young'] = train['Age'].apply(lambda x: is_young(x))
train['young_and_underpaid'] = train.apply(lambda x: young_and_low_daily_rate(x), axis = 1)
train['worklife_stock'] = train.apply(lambda x: x['WorkLifeBalance'] + x['StockOptionLevel'], axis = 1)
train['Job'] = train.apply(lambda x: x['JobInvolvement'] + x['JobLevel'] + x['JobSatisfaction'], axis = 1)

original['is_young'] = original['Age'].apply(lambda x: is_young(x))
original['young_and_underpaid'] = original.apply(lambda x: young_and_low_daily_rate(x), axis = 1)
original['worklife_stock'] = original.apply(lambda x: x['WorkLifeBalance'] + x['StockOptionLevel'], axis = 1)
original['Job'] = original.apply(lambda x: x['JobInvolvement'] + x['JobLevel'] + x['JobSatisfaction'], axis = 1)

test['is_young'] = test['Age'].apply(lambda x: is_young(x))
test['young_and_underpaid'] = test.apply(lambda x: young_and_low_daily_rate(x), axis = 1)
test['worklife_stock'] = test.apply(lambda x: x['WorkLifeBalance'] + x['StockOptionLevel'], axis = 1)
test['Job'] = test.apply(lambda x: x['JobInvolvement'] + x['JobLevel'] + x['JobSatisfaction'], axis = 1)

# %% [markdown]
# ## Correlation matrix (Heatmap Style)

# %%
train['source'] = 1
test['source'] = 1
original['source'] = 0

num_features = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 
                'MonthlyRate','NumCompaniesWorked', 'PercentSalaryHike', 'TrainingTimesLastYear', 
                'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
                'YearsWithCurrManager']

cat_features = ['BusinessTravel', 'Department','Education', 'EducationField', 'EnvironmentSatisfaction',
                'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
                'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'Job',
                'TrainingTimesLastYear', 'WorkLifeBalance','is_young', 'young_and_underpaid', 'worklife_stock']

target = 'Attrition'

# %%
# Train Set
corrmat = train[num_features+[target]].corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, square=True, annot=True, fmt='.2f', cmap='seismic', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
# Original
corrmat = original[num_features+[target]].corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, square=True, annot=True, fmt='.2f', cmap='seismic', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train Model

# %%
train = pd.concat([train, original])
train.reset_index(inplace=True, drop=True)

# %%
all_features = train.drop(['id', target], axis=1).columns

# %%
from category_encoders import WOEEncoder

for col in cat_features:
    train[col] = train[col].astype(str)
    test[col] = test[col].astype(str)
    
woe = WOEEncoder(drop_invariant=True, randomized = True)
woe.fit(train[all_features], train['Attrition'], cols = cat_features)
train[all_features] = woe.transform(train[all_features])
test[all_features] = woe.transform(test[all_features])

# %% [markdown]
# ## XGBClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

clfs = []
scores1 = []
scores2 = []
kf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

params = {'max_depth': 3,
          'learning_rate': 0.1,
          'min_child_weight': 5,
          'subsample': 0.7,
          'colsample_bytree': 0.3,
          'tree_method': 'gpu_hist'
         }

for i, (train_index, val_index) in enumerate(kf.split(train, y=train['Attrition'])):
    X_train, X_val = train[all_features].loc[train_index], train[all_features].loc[val_index]
    y_train, y_val = train[target][train_index], train[target][val_index]
    
    X_val_without_original, y_val_without_original = X_val[X_val['source'] == 1], y_val.loc[X_val[X_val['source'] == 1].index]
    
    clf = XGBClassifier(**params,
                        n_estimators=20000,
                        seed=42)
    
    clf.fit(X_train.values, y_train,
            early_stopping_rounds=100, 
            eval_set=[(X_val_without_original.values, y_val_without_original)], 
            eval_metric=['auc'],
            verbose=1000)
    
    preds1 = clf.predict_proba(X_val_without_original.values)
    auc1 = roc_auc_score(y_val_without_original, preds1[:, 1])
    preds2 = clf.predict_proba(X_val.values)
    auc2 = roc_auc_score(y_val, preds2[:, 1])
    
    clfs.append(clf)
    scores1.append(auc1)
    scores2.append(auc2)
    print(f'Score on fold {i} (without original data): {auc1}')
    print(f'Score on fold {i} (with original data): {auc2}')
    print('-'*75)
    
print(f'Mean score across all folds (without original data): {np.mean(scores1)}')
print(f'Mean score across all folds (with original data): {np.mean(scores2)}')
# Out:
# [0]	validation_0-auc:0.60239
# [115]	validation_0-auc:0.82847
# Score on fold 0 (without original data): 0.840632603406326
# Score on fold 0 (with original data): 0.7987252599798724
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.69719
# [340]	validation_0-auc:0.85494
# Score on fold 1 (without original data): 0.877914951989026
# Score on fold 1 (with original data): 0.869590741361959
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.71215
# [279]	validation_0-auc:0.87159
# Score on fold 2 (without original data): 0.8906403940886699
# Score on fold 2 (with original data): 0.8857765850385776
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.58845
# [189]	validation_0-auc:0.92213
# Score on fold 3 (without original data): 0.9259415996614473
# Score on fold 3 (with original data): 0.8773062730627307
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.70569
# [353]	validation_0-auc:0.88980
# Score on fold 4 (without original data): 0.8964705882352941
# Score on fold 4 (with original data): 0.8640556860114056
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.72121
# [180]	validation_0-auc:0.84933
# Score on fold 5 (without original data): 0.8529017857142858
# Score on fold 5 (with original data): 0.8765124860550931
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.65835
# [335]	validation_0-auc:0.91950
# Score on fold 6 (without original data): 0.9232804232804233
# Score on fold 6 (with original data): 0.8603793014674334
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.70834
# [177]	validation_0-auc:0.87338
# Score on fold 7 (without original data): 0.8739072847682119
# Score on fold 7 (with original data): 0.8818330043765554
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.71250
# [181]	validation_0-auc:0.81299
# Score on fold 8 (without original data): 0.8353896103896105
# Score on fold 8 (with original data): 0.8445286195286195
# ---------------------------------------------------------------------------
# [0]	validation_0-auc:0.81641
# [137]	validation_0-auc:0.84939
# Score on fold 9 (without original data): 0.8758680555555556
# Score on fold 9 (with original data): 0.8128787878787879
# ---------------------------------------------------------------------------
# Mean score across all folds (without original data): 0.8792947297088849
# Mean score across all folds (with original data): 0.8571586744761033

# %% [markdown]
# ## LGBMClassifier

# %%
scores1 = []
scores2 = []

params = {'learning_rate': 0.09,
          'num_leaves': 195,
          'max_depth': 2,
          'min_child_samples': 46,
          'reg_alpha': 0.05,
          'reg_lambda': 0.1,
          'subsample': 0.45,
          'colsample_bytree': 0.3}

for i, (train_index, val_index) in enumerate(kf.split(train, y=train['Attrition'])):
    X_train, X_val = train[all_features].loc[train_index], train[all_features].loc[val_index]
    y_train, y_val = train[target][train_index], train[target][val_index]
    
    X_val_without_original, y_val_without_original = X_val[X_val['source'] == 1], y_val.loc[X_val[X_val['source'] == 1].index]
    
    clf = lgbm.LGBMClassifier(**params,
                              n_estimators=20000,
                              metric='auc',
                              random_state=42)
    
    clf.fit(X_train.values, y_train, 
            eval_set=[(X_val_without_original.values, y_val_without_original)],
            eval_metric=['auc'],
            callbacks=[lgbm.early_stopping(100, verbose=True)])
            
    preds1 = clf.predict_proba(X_val_without_original.values)
    auc1 = roc_auc_score(y_val_without_original, preds1[:, 1])
    preds2 = clf.predict_proba(X_val.values)
    auc2 = roc_auc_score(y_val, preds2[:, 1])
    
    clfs.append(clf)
    scores1.append(auc1)
    scores2.append(auc2)
    print(f'Score on fold {i} (without original data): {auc1}')
    print(f'Score on fold {i} (with original data): {auc2}')
    print('-'*75)
    
print(f'Mean score across all folds (without original data): {np.mean(scores1)}')
print(f'Mean score across all folds (with original data): {np.mean(scores2)}')
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's auc: 0.836172
# Score on fold 0 (without original data): 0.8361719383617194
# Score on fold 0 (with original data): 0.8449345857094934
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [226]	valid_0's auc: 0.868313
# Score on fold 1 (without original data): 0.868312757201646
# Score on fold 1 (with original data): 0.8721905400872191
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [282]	valid_0's auc: 0.896223
# Score on fold 2 (without original data): 0.8962233169129721
# Score on fold 2 (with original data): 0.8888795706138878
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [100]	valid_0's auc: 0.928058
# Score on fold 3 (without original data): 0.9280575539568345
# Score on fold 3 (with original data): 0.8764676283126468
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [216]	valid_0's auc: 0.858824
# Score on fold 4 (without original data): 0.8588235294117647
# Score on fold 4 (with original data): 0.841580006709158
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [367]	valid_0's auc: 0.855804
# Score on fold 5 (without original data): 0.8558035714285713
# Score on fold 5 (with original data): 0.8688749678194456
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.926682
# Score on fold 6 (without original data): 0.926681783824641
# Score on fold 6 (with original data): 0.862095597700163
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [41]	valid_0's auc: 0.859868
# Score on fold 7 (without original data): 0.8598675496688742
# Score on fold 7 (with original data): 0.8697331159358105
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.828896
# Score on fold 8 (without original data): 0.8288961038961039
# Score on fold 8 (with original data): 0.8278619528619529
# ---------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's auc: 0.900608
# Score on fold 9 (without original data): 0.900607638888889
# Score on fold 9 (with original data): 0.7809343434343435
# ---------------------------------------------------------------------------
# Mean score across all folds (without original data): 0.8759445743552016
# Mean score across all folds (with original data): 0.8533552309184123

# %% [markdown]
# ## CatBoostClassifier

# %%
scores1 = []
scores2 = []

params = {'loss_function': 'CrossEntropy',
          'learning_rate': 0.76,
          'l2_leaf_reg': 0.014,
          'colsample_bylevel': 0.06,
          'depth': 1,
          'boosting_type': 'Plain',
          'bootstrap_type': 'Bernoulli',
          'min_data_in_leaf': 18,
          'subsample': 0.8}

for i, (train_index, val_index) in enumerate(kf.split(train, y=train['Attrition'])):
    X_train, X_val = train[all_features].loc[train_index], train[all_features].loc[val_index]
    y_train, y_val = train[target][train_index], train[target][val_index]
    
    X_val_without_original, y_val_without_original = X_val[X_val['source'] == 1], y_val.loc[X_val[X_val['source'] == 1].index]
    
    clf = CatBoostClassifier(**params,
                            iterations=20000,
                            eval_metric='AUC',
                            random_state=42)
    
    clf.fit(X_train.values, y_train, 
            eval_set=(X_val_without_original.values, y_val_without_original),
            early_stopping_rounds=100, verbose=1000)
    
    preds1 = clf.predict_proba(X_val_without_original.values)
    auc1 = roc_auc_score(y_val_without_original, preds1[:, 1])
    preds2 = clf.predict_proba(X_val.values)
    auc2 = roc_auc_score(y_val, preds2[:, 1])
    
    clfs.append(clf)
    scores1.append(auc1)
    scores2.append(auc2)
    print(f'Score on fold {i} (without original data): {auc1}')
    print(f'Score on fold {i} (with original data): {auc2}')
    print('-'*85)
    
print(f'Mean score across all folds (without original data): {np.mean(scores1)}')
print(f'Mean score across all folds (with original data): {np.mean(scores2)}')
# Out:
# 0:	test: 0.6265207	best: 0.6265207 (0)	total: 54.3ms	remaining: 18m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8625304136
# bestIteration = 249
#
# Shrink model to first 250 iterations.
# Score on fold 0 (without original data): 0.8625304136253042
# Score on fold 0 (with original data): 0.8623783965112379
# -------------------------------------------------------------------------------------
# 0:	test: 0.5216049	best: 0.5216049 (0)	total: 1.01ms	remaining: 20.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8789437586
# bestIteration = 170
#
# Shrink model to first 171 iterations.
# Score on fold 1 (without original data): 0.8789437585733882
# Score on fold 1 (with original data): 0.8874538745387454
# -------------------------------------------------------------------------------------
# 0:	test: 0.4824302	best: 0.4824302 (0)	total: 835us	remaining: 16.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9047619048
# bestIteration = 254
#
# Shrink model to first 255 iterations.
# Score on fold 2 (without original data): 0.9047619047619048
# Score on fold 2 (with original data): 0.8877054679637706
# -------------------------------------------------------------------------------------
# 0:	test: 0.5120609	best: 0.5120609 (0)	total: 868us	remaining: 17.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9166314008
# bestIteration = 91
#
# Shrink model to first 92 iterations.
# Score on fold 3 (without original data): 0.9166314007617434
# Score on fold 3 (with original data): 0.8990271720899028
# -------------------------------------------------------------------------------------
# 0:	test: 0.5021569	best: 0.5021569 (0)	total: 798us	remaining: 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8694117647
# bestIteration = 73
#
# Shrink model to first 74 iterations.
# Score on fold 4 (without original data): 0.8694117647058823
# Score on fold 4 (with original data): 0.8662361623616237
# -------------------------------------------------------------------------------------
# 0:	test: 0.6285714	best: 0.6285714 (0)	total: 1.17ms	remaining: 23.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8549107143
# bestIteration = 111
#
# Shrink model to first 112 iterations.
# Score on fold 5 (without original data): 0.8549107142857143
# Score on fold 5 (with original data): 0.877542263794731
# -------------------------------------------------------------------------------------
# 0:	test: 0.6326531	best: 0.6326531 (0)	total: 962us	remaining: 19.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.925170068
# bestIteration = 306
#
# Shrink model to first 307 iterations.
# Score on fold 6 (without original data): 0.9251700680272109
# Score on fold 6 (with original data): 0.8730798935896334
# -------------------------------------------------------------------------------------
# 0:	test: 0.7378808	best: 0.7378808 (0)	total: 858us	remaining: 17.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8532450331
# bestIteration = 107
#
# Shrink model to first 108 iterations.
# Score on fold 7 (without original data): 0.8532450331125827
# Score on fold 7 (with original data): 0.8553162275808804
# -------------------------------------------------------------------------------------
# 0:	test: 0.6935065	best: 0.6935065 (0)	total: 935us	remaining: 18.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8168831169
# bestIteration = 79
#
# Shrink model to first 80 iterations.
# Score on fold 8 (without original data): 0.816883116883117
# Score on fold 8 (with original data): 0.8388047138047137
# -------------------------------------------------------------------------------------
# 0:	test: 0.7812500	best: 0.7812500 (0)	total: 814us	remaining: 16.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8823784722
# bestIteration = 122
#
# Shrink model to first 123 iterations.
# Score on fold 9 (without original data): 0.8823784722222222
# Score on fold 9 (with original data): 0.836111111111111
# -------------------------------------------------------------------------------------
# Mean score across all folds (without original data): 0.8764866646959069
# Mean score across all folds (with original data): 0.8683655283346351

# %% [markdown]
# ## Feature importances

# %%
plt.figure(figsize=(12,12))
imp = np.zeros(35)
for clf in clfs[:10]:
    imp+= clf.feature_importances_
    
print('----------------------------XGBoost----------------------------')
plt.barh([all_features[i] for i in np.argsort(imp/10)], sorted(imp/10))
plt.show()
# Out:
# ----------------------------XGBoost----------------------------

# %%
plt.figure(figsize=(12,12))
imp = np.zeros(35)
for clf in clfs[10:20]:
    imp+= clf.feature_importances_
    
print('----------------------------LGBM----------------------------')
plt.barh([all_features[i] for i in np.argsort(imp/10)], sorted(imp/10))
plt.show()
# Out:
# ----------------------------LGBM----------------------------

# %%
plt.figure(figsize=(12,12))
imp = np.zeros(35)
for clf in clfs[20:]:
    imp+= clf.feature_importances_
    
print('----------------------------CatBoost----------------------------')
plt.barh([all_features[i] for i in np.argsort(imp/10)], sorted(imp/10))
plt.show()
# Out:
# ----------------------------CatBoost----------------------------

# %% [markdown]
# # Making submission

# %%
test_preds1 = []
test_preds2 = []
test_preds3 = []

for clf in clfs[:10]:
    preds = clf.predict_proba(test[all_features].values)
    test_preds1.append(preds[:, 1])
    
for clf in clfs[10:20]:
    preds = clf.predict_proba(test[all_features].values)
    test_preds2.append(preds[:, 1])
    
for clf in clfs[20:]:
    preds = clf.predict_proba(test[all_features].values)
    test_preds3.append(preds[:, 1])

# %%
test_preds1 = np.stack(test_preds1).mean(0)
test_preds2 = np.stack(test_preds2).mean(0)
test_preds3 = np.stack(test_preds3).mean(0)

# %%
test_preds = test_preds1*0.3 + test_preds2*0.2 + test_preds3*0.5

# %%
submission = pd.DataFrame(data={'id': test.id, 'Attrition': test_preds})
submission.head()
# Out:
#      id  Attrition
# 0  1677   0.188407
# 1  1678   0.137034
# 2  1679   0.044329
# 3  1680   0.061096
# 4  1681   0.512708

# %%
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# **If you found this notebook useful, please upvote!**
#
# **Thank you!🙏🙏🙏**
